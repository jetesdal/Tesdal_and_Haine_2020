# %%
import numpy as np
import xarray as xr
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.legend import Legend
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/compat/_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Load datasets

# %%
lfwc_spna_cm = pd.read_csv('../Curry_and_Mauritzen_2005_fig02_fw_spna.csv',
                           header=None,names = ["time", "dF"])
lfwc_spna_cm.time = pd.DatetimeIndex(pd.date_range('1955-06-30','1995-06-30',freq='60M'))
lfwc_spna_cm.set_index(['time'],inplace=True)

# %%
lfwc_nsea_cm = pd.read_csv('../Curry_and_Mauritzen_2005_fig02_fw_nsea.csv',
                           header=None,names = ["time", "dF"])
lfwc_nsea_cm.time = pd.DatetimeIndex(pd.date_range('1955-06-30','2000-06-30',freq='60M'))
lfwc_nsea_cm.set_index(['time'],inplace=True)

# %%
lfwc_spna_en_pentad = xr.open_dataset('/mnt/efs/data/lfwc/en4_lfwc_spna_pentad.nc')
lfwc_spna_en_monthly = xr.open_dataset('/mnt/efs/data/lfwc/en4_lfwc_spna_monthly.nc').lfwc
lfwc_spna_ec_monthly = xr.open_dataset('/mnt/efs/data/lfwc/eccov4r4_lfwc_spna_monthly_anom.nc').lfwc

lfwc_nsea_en_pentad = xr.open_dataset('/mnt/efs/data/lfwc/en4_lfwc_nsea_pentad.nc')
lfwc_nsea_en_monthly = xr.open_dataset('/mnt/efs/data/lfwc/en4_lfwc_nsea_monthly.nc').lfwc
lfwc_nsea_ec_monthly = xr.open_dataset('/mnt/efs/data/lfwc/eccov4r4_lfwc_nsea_monthly_anom.nc').lfwc

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
    
ax1.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax1.plot(lfwc_spna_en_monthly.time, lfwc_spna_en_monthly, lw=1, color='k',linestyle='-',label='EN4 (monthly)')
p=ax1.plot(lfwc_spna_ec_monthly.time,lfwc_spna_ec_monthly,lw=3,color='m',linestyle='-',label=None)
ax1.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax1.set_ylim([-13500,13500])
ax1.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

ax1.set_yticks(np.arange(-12000,14000,2000))
ax1.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax1.set_ylabel(r'Freshwater storage anomaly (km$^3$)',color='k',fontsize=14)
for tl in ax1.get_yticklabels():
    tl.set_color('k')
ax1.legend(loc='upper left',frameon=False, fontsize=14)
leg = Legend(ax1, p, ['ECCOv4 (monthly)'],loc='upper right', frameon=False, fontsize=14)
ax1.add_artist(leg)

ax2 = ax1.twinx()
ax2.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax2.plot(lfwc_spna_cm.index, lfwc_spna_cm.dF, lw=3, color='r', linestyle='-',marker='o', label='HydroBase2 (CM05)')
ax2.plot(lfwc_spna_en_pentad.time, lfwc_spna_en_pentad.lfwc, lw=3, color='b', linestyle='-',marker='o', 
         label='EN4 (pentad)')


ax2.get_yaxis().set_visible(False)
ax2.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax2.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax2.tick_params(axis = 'x', which = 'major', labelsize = 12)
ax2.set_ylim([-13500,13500])
ax2.set_ylabel(r'Storage anomaly in km$^3$ (after CM05)',color='k',fontsize=12)
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ax2.legend(loc='lower right',frameon=False, fontsize=14)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
    
ax1.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax1.plot(lfwc_nsea_en_monthly.time, lfwc_nsea_en_monthly, lw=1, color='k',linestyle='-',label='EN4 (monthly)')
p=ax1.plot(lfwc_nsea_ec_monthly.time,lfwc_nsea_ec_monthly,lw=3,color='m',linestyle='-',label=None)
ax1.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax1.set_ylim([-7000,7000])
ax1.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

ax1.set_yticks(np.arange(-6000,8000,2000))
ax1.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax1.set_ylabel(r'Freshwater storage anomaly (km$^3$)',color='k',fontsize=14)
for tl in ax1.get_yticklabels():
    tl.set_color('k')
ax1.legend(loc='upper left',frameon=False, fontsize=14)
leg = Legend(ax1, p, ['ECCOv4 (monthly)'],loc='upper right', frameon=False, fontsize=14)
ax1.add_artist(leg)

ax2 = ax1.twinx()
ax2.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax2.plot(lfwc_nsea_cm.index, lfwc_nsea_cm.dF, lw=3, color='r', linestyle='-',marker='o', label='HydroBase2 (CM05)')
ax2.plot(lfwc_nsea_en_pentad.time, lfwc_nsea_en_pentad.lfwc, lw=3, color='b', linestyle='-',marker='o', 
         label='EN4 (pentad)')

ax2.get_yaxis().set_visible(False)
ax2.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax2.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax2.tick_params(axis = 'x', which = 'major', labelsize = 12)
ax2.set_ylim([-7000,7000])
ax2.set_ylabel(r'Storage anomaly in km$^3$ (after CM05)',color='k',fontsize=12)
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ax2.legend(loc='lower right',frameon=False, fontsize=14)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %% [markdown]
# ## Maps

# %%
import statsmodels.api as sm

import shapely
import geopandas as gpd
import salem
import cartopy

import matplotlib.ticker as mticker

# %%
def get_gdf_patch(coords_patch):
    # Replace each pair of points by 10 points for projected map
    geometry = []
    segments = zip(coords_patch[:-2:2], coords_patch[1:-1:2], coords_patch[2::2], 
                   coords_patch[3::2])
    
    for line in [shapely.geometry.LineString([(x1, y1), (x2, y2)]) for (x1,y1,x2,y2) in segments]:
        for length in np.linspace(0,1,11):
            geometry.append( line.interpolate(length, normalized=True) )
        
    gdf_patch = gpd.GeoDataFrame([], geometry=geometry)
    
    # Convert Points to Polygo
    gdf_patch['geometry'] = gdf_patch['geometry'].apply(lambda x: x.coords[0])
    
    gdf_patch['shape_id'] = 0
    gdf_patch = gdf_patch.groupby('shape_id')['geometry'].apply(lambda x: shapely.geometry.Polygon(x.tolist())).reset_index()
    gdf_patch = gpd.GeoDataFrame(gdf_patch, geometry = 'geometry')
    
    # Salem uses this attribute:
    gdf_patch.crs = {'init': 'epsg:4326'}
    
    return gdf_patch

# %%
coords_spna = [-9.4, 50,-56.8, 50,-67.5, 62.3,-61.6, 66.7,-35, 66.7,-22.1, 66.1,-3.8, 59,-9.4, 50]
coords_nsea = [-3.8, 59,-22.1, 66.1,-35, 66.7,-29, 70,-25, 80,20, 80,20, 70,11, 64,5, 60,-3.8,59]

# %%
gdf_spna = get_gdf_patch(coords_spna)
gdf_nsea = get_gdf_patch(coords_nsea)
# Out:
# /usr/local/lib/python3.6/dist-packages/geopandas/geodataframe.py:830: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
# /usr/local/lib/python3.6/dist-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /usr/local/lib/python3.6/dist-packages/geopandas/geodataframe.py:830: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
# ...

# %% [markdown]
# ### Load datasets

# %%
# ECCOv4r4
ec = xr.open_dataset('/mnt/efs/data/ecco/eccov4r4_interp_salt.nc')

# %%
# HadOBS EN4
en = xr.open_dataset('/mnt/efs/data/hadobs/salinity.nc')

# Add area
nc = xr.open_dataset('/mnt/efs/data/hadobs/hadobs_en4_area.nc')
en['area'] = nc.area
en.area.attrs= {'units': 'm^2','long_name': 'Grid area'}

# %% [markdown]
# ## Liquid freshwater content
# The freshwater content (in meters) for each grid point is estimated as
# $$ h_{fw} = \int_D^\eta f \, dz = \int_D^\eta \frac{S_{ref} - S}{S_{ref}} \, dz$$

# %%
psal_ref = 35.0

# %% [markdown]
# ### Subselect salinity fields

# %%
south,north,west,east = 40,90,-110,45

# %% [markdown]
# #### EN4

# %%
tstart = '1900-01-15'
tend = '2017-12-31'

# %%
# EN4
psal_en = en.salinity.sel(time=slice(tstart,tend),lat=slice(south,north),lon=slice(west,east))

# %%
f_en = (psal_ref - psal_en)/psal_ref

# %%
depth_bnds = en.depth_bnds
dz = (depth_bnds[:,1]-depth_bnds[:,0])
h_fw_en = (f_en * dz).sum('depth')

# %% [markdown]
# ### Annual mean freshwater content

# %%
h_fw_en_annual = h_fw_en.groupby('time.year').mean('time') - h_fw_en.mean('time')

# %% [markdown]
# ### Integrate over area

# %%
Vfw_spna_en = (h_fw_en_annual.salem.roi(shape=gdf_spna.loc[[0]]) * en.area).sum(dim=['lat','lon'])*1e-9
Vfw_nsea_en = (h_fw_en_annual.salem.roi(shape=gdf_nsea.loc[[0]]) * en.area).sum(dim=['lat','lon'])*1e-9

# %%
df = Vfw_spna_en.to_dataframe(name='spna')
df['nsea'] = Vfw_nsea_en.to_dataframe(name='nsea')

# Convert time
df['time'] = pd.DatetimeIndex([datetime.datetime(year, 7, 2) for year in df.reset_index()['year']])

# Select years for linear fit
df = df[((df.index > 1997)&(df.index < 2006))|((df.index > 2009)&(df.index <= 2017))]

# %% [markdown]
# ### Linear fit

# %%
def get_OLS_fit(df,var):
    model = sm.OLS(df[var].values, sm.add_constant(df.index.values))
    results = model.fit()
    
    if results.params[1]>0:
        err = np.abs(results.conf_int()[1][0]-results.params[1])
    elif results.params[1]<0:
        err = np.abs(results.params[1]-results.conf_int()[1][1])
    return results.params[1],results.params[0],err

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax1.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax1.plot(lfwc_spna_en_monthly.time, lfwc_spna_en_monthly, lw=1, color='k',linestyle='-',label='EN4 (monthly)')
ax1.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax1.set_ylim([-13500,13500])
ax1.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax1.set_yticks(np.arange(-12000,14000,2000))
ax1.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax1.set_ylabel(r'Freshwater storage anomaly (km$^3$)',color='k',fontsize=14)
for tl in ax1.get_yticklabels():
    tl.set_color('k')
ax1.legend(loc='upper left',frameon=False, fontsize=14)

ax2 = ax1.twinx()
ax2.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax2.plot(lfwc_spna_cm.index, lfwc_spna_cm.dF, lw=3, color='r', linestyle='-',marker='o', label='HydroBase2 (CM05)')
ax2.plot(lfwc_spna_en_pentad.time, lfwc_spna_en_pentad.lfwc, lw=3, color='b', linestyle='-',marker='o', 
         label='EN4 (pentad)')
ax2.plot(df.time,df.spna,color='k',ls='none',marker='o',ms=10,alpha=0.4)
ax2.plot(df[df.index < 2006].time, get_OLS_fit(df[df.index < 2006],'spna')[0]*df[df.index < 2006].index+\
         get_OLS_fit(df[df.index < 2006],'spna')[1], c='k', lw=5, linestyle='-')
ax2.plot(df[df.index > 2009].time, get_OLS_fit(df[df.index > 2009],'spna')[0]*df[df.index > 2009].index+\
         get_OLS_fit(df[df.index > 2009],'spna')[1], c='k', lw=5, linestyle='-')
ax2.get_yaxis().set_visible(False)
ax2.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax2.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax2.tick_params(axis = 'x', which = 'major', labelsize = 12)
ax2.set_ylim([-13500,13500])
ax2.set_ylabel(r'Storage anomaly in km$^3$ (after CM05)',color='k',fontsize=12)
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ax2.legend(loc='lower right',frameon=False, fontsize=14)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
    
ax1.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax1.plot(lfwc_nsea_en_monthly.time, lfwc_nsea_en_monthly, lw=1, color='k',linestyle='-',label='EN4 (monthly)')
ax1.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax1.set_ylim([-7000,7000])
ax1.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax1.set_yticks(np.arange(-6000,8000,2000))
ax1.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax1.set_ylabel(r'Freshwater storage anomaly (km$^3$)',color='k',fontsize=14)
for tl in ax1.get_yticklabels():
    tl.set_color('k')
ax1.legend(loc='upper left',frameon=False, fontsize=14)

ax2 = ax1.twinx()
ax2.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax2.plot(lfwc_nsea_cm.index, lfwc_nsea_cm.dF, lw=3, color='r', linestyle='-',marker='o', label='HydroBase2 (CM05)')
ax2.plot(lfwc_nsea_en_pentad.time, lfwc_nsea_en_pentad.lfwc, lw=3, color='b', linestyle='-',marker='o', 
         label='EN4 (pentad)')
ax2.plot(df.time,df.nsea,color='k',ls='none',marker='o',ms=10,alpha=0.4)
ax2.plot(df[df.index < 2006].time, get_OLS_fit(df[df.index < 2006],'nsea')[0]*df[df.index < 2006].index+\
         get_OLS_fit(df[df.index < 2006],'nsea')[1], c='k', lw=5, linestyle='-')
ax2.plot(df[df.index > 2009].time, get_OLS_fit(df[df.index > 2009],'nsea')[0]*df[df.index > 2009].index+\
         get_OLS_fit(df[df.index > 2009],'nsea')[1], c='k', lw=5, linestyle='-')
ax2.get_yaxis().set_visible(False)
ax2.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax2.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax2.tick_params(axis = 'x', which = 'major', labelsize = 12)
ax2.set_ylim([-7000,7000])
ax2.set_ylabel(r'Storage anomaly in km$^3$ (after CM05)',color='k',fontsize=12)
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ax2.legend(loc='lower right',frameon=False, fontsize=14)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %% [markdown]
# #### ECCO

# %%
tstart = '1992-01-01'
tend = '2017-12-31'

psal_ec = ec.salinity.sel(time=slice(tstart,tend),lat=slice(south,north),lon=slice(west,east))

f_ec = (psal_ref - psal_ec)/psal_ref
h_fw_ec = (f_ec * ec.dz).sum('depth')

# %% [markdown]
# ### Annual mean freshwater content: ECCOv4

# %%
h_fw_ec_annual = h_fw_ec.groupby('time.year').mean('time') - h_fw_ec.mean('time')

# %% [markdown]
# ### Integrate over area

# %%
Vfw_spna_ec = (h_fw_ec_annual.salem.roi(shape=gdf_spna.loc[[0]]) * ec.area).sum(dim=['lat','lon'])*1e-9
Vfw_nsea_ec = (h_fw_ec_annual.salem.roi(shape=gdf_nsea.loc[[0]]) * ec.area).sum(dim=['lat','lon'])*1e-9

# %%
df = Vfw_spna_ec.to_dataframe(name='spna')
df['nsea'] = Vfw_nsea_ec.to_dataframe(name='nsea')

# Convert time
df['time'] = pd.DatetimeIndex([datetime.datetime(year, 7, 2) for year in df.reset_index()['year']])

# Select years for linear fit
df = df[((df.index > 1997)&(df.index < 2006))|((df.index > 2009)&(df.index <= 2017))]

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
    
ax1.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax1.plot(lfwc_spna_en_monthly.time, lfwc_spna_en_monthly, lw=1, color='k',linestyle='-',label='EN4 (monthly)')
p=ax1.plot(lfwc_spna_ec_monthly.time,lfwc_spna_ec_monthly,lw=3,color='m',linestyle='-',label=None)
ax1.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax1.set_ylim([-13500,13500])
ax1.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax1.set_yticks(np.arange(-12000,14000,2000))
ax1.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax1.set_ylabel(r'Freshwater storage anomaly (km$^3$)',color='k',fontsize=14)
for tl in ax1.get_yticklabels():
    tl.set_color('k')
ax1.legend(loc='upper left',frameon=False, fontsize=14)
leg = Legend(ax1, p, ['ECCOv4 (monthly)'],loc='upper right', frameon=False, fontsize=14)
ax1.add_artist(leg)

ax2 = ax1.twinx()
ax2.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax2.plot(lfwc_spna_cm.index, lfwc_spna_cm.dF, lw=3, color='r', linestyle='-',marker='o', label='HydroBase2 (CM05)')
ax2.plot(lfwc_spna_en_pentad.time,lfwc_spna_en_pentad.lfwc,lw=3,color='b',linestyle='-',marker='o',
         label='EN4 (pentad)')
ax2.plot(df.time,df.spna,color='m',ls='none',marker='o',ms=10,alpha=0.4)
ax2.plot(df[df.index < 2006].time, get_OLS_fit(df[df.index < 2006],'spna')[0]*df[df.index < 2006].index+\
         get_OLS_fit(df[df.index < 2006],'spna')[1], c='m', lw=5, linestyle='-')
ax2.plot(df[df.index > 2009].time, get_OLS_fit(df[df.index > 2009],'spna')[0]*df[df.index > 2009].index+\
         get_OLS_fit(df[df.index > 2009],'spna')[1], c='m', lw=5, linestyle='-')
ax2.get_yaxis().set_visible(False)
ax2.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax2.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax2.tick_params(axis = 'x', which = 'major', labelsize = 12)
ax2.set_ylim([-13500,13500])
ax2.set_ylabel(r'Storage anomaly in km$^3$ (after CM05)',color='k',fontsize=12)
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ax2.legend(loc='lower right',frameon=False, fontsize=14)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
    
ax1.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax1.plot(lfwc_nsea_en_monthly.time, lfwc_nsea_en_monthly, lw=1, color='k',linestyle='-',label='EN4 (monthly)')
p=ax1.plot(lfwc_nsea_ec_monthly.time,lfwc_nsea_ec_monthly,lw=3,color='m',linestyle='-',label=None)
ax1.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax1.set_ylim([-7000,7000])
ax1.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax1.set_yticks(np.arange(-6000,8000,2000))
ax1.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax1.set_ylabel(r'Freshwater storage anomaly (km$^3$)',color='k',fontsize=14)
for tl in ax1.get_yticklabels():
    tl.set_color('k')
ax1.legend(loc='upper left',frameon=False, fontsize=14)
leg = Legend(ax1, p, ['ECCOv4 (monthly)'],loc='upper right', frameon=False, fontsize=14)
ax1.add_artist(leg)

ax2 = ax1.twinx()
ax2.axhline(y=0, xmin=0, xmax=1, linewidth=0.5, color = 'k')
ax2.plot(lfwc_nsea_cm.index, lfwc_nsea_cm.dF, lw=3, color='r', linestyle='-',marker='o', label='HydroBase2 (CM05)')
ax2.plot(lfwc_nsea_en_pentad.time, lfwc_nsea_en_pentad.lfwc, lw=3, color='b', linestyle='-',marker='o', 
         label='EN4 (pentad)')
ax2.plot(df.time,df.nsea,color='m',ls='none',marker='o',ms=10,alpha=0.4)
ax2.plot(df[df.index < 2006].time, get_OLS_fit(df[df.index < 2006],'nsea')[0]*df[df.index < 2006].index+\
         get_OLS_fit(df[df.index < 2006],'nsea')[1], c='m', lw=5, linestyle='-')
ax2.plot(df[df.index > 2009].time, get_OLS_fit(df[df.index > 2009],'nsea')[0]*df[df.index > 2009].index+\
         get_OLS_fit(df[df.index > 2009],'nsea')[1], c='m', lw=5, linestyle='-')
ax2.get_yaxis().set_visible(False)
ax2.set_xlim([datetime.date(1950, 1, 1), datetime.date(2018, 1, 31)])
ax2.set_xticks(pd.date_range('1950-06-30','2015-06-30',freq='60M'))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax2.tick_params(axis = 'x', which = 'major', labelsize = 12)
ax2.set_ylim([-7000,7000])
ax2.set_ylabel(r'Storage anomaly in km$^3$ (after CM05)',color='k',fontsize=12)
for tl in ax2.get_yticklabels():
    tl.set_color('k')
ax2.legend(loc='lower right',frameon=False, fontsize=14)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %% [markdown]
# ### Spatial trends for 1998-2005 and 2010-2017

# %%
def get_trend(data):
    return np.polyfit(t, data, 1)[0]

# %%
def get_ratio(data):
    try:
        model = sm.OLS(data,sm.add_constant(t))
        results = model.fit()
        if results.params[1]>0:
            err = np.abs(results.conf_int()[1][0]-results.params[1])
        elif results.params[1]<0:
            err = np.abs(results.params[1]-results.conf_int()[1][1])
        elif results.params[1]==0:
            err = results.bse[1]
        else:
            err = np.nan
    
        return results.params[1]/err
    
    except ValueError:
        return np.nan
    
    except RuntimeError:
        return np.nan

# %%
t = h_fw_ec_annual.sel(year=slice(1998,2005)).year.astype(int)
h_fw_ec_trend9805 = xr.DataArray(np.apply_along_axis(get_trend, 2, 
                                            h_fw_ec_annual.sel(year=slice(1998,2005)).transpose('lat','lon','year')),
                                 coords=[h_fw_ec_annual.lat,h_fw_ec_annual.lon],dims=['lat','lon'])
h_fw_ec_ratio9805 = xr.DataArray(np.apply_along_axis(get_ratio, 2, 
                                            h_fw_ec_annual.sel(year=slice(1998,2005)).transpose('lat','lon','year')),
                                 coords=[h_fw_ec_annual.lat,h_fw_ec_annual.lon],dims=['lat','lon'])

t = h_fw_ec_annual.sel(year=slice(2010,2017)).year.astype(int)
h_fw_ec_trend1017 = xr.DataArray(np.apply_along_axis(get_trend, 2, 
                                            h_fw_ec_annual.sel(year=slice(2010,2017)).transpose('lat','lon','year')),
                                 coords=[h_fw_ec_annual.lat,h_fw_ec_annual.lon],dims=['lat','lon'])
h_fw_ec_ratio1017 = xr.DataArray(np.apply_along_axis(get_ratio, 2, 
                                            h_fw_ec_annual.sel(year=slice(2010,2017)).transpose('lat','lon','year')),
                                 coords=[h_fw_ec_annual.lat,h_fw_ec_annual.lon],dims=['lat','lon'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in double_scalars

# %%
t = h_fw_en_annual.sel(year=slice(1998,2005)).year.astype(int)
h_fw_en_trend9805 = xr.DataArray(np.apply_along_axis(get_trend, 2, 
                                            h_fw_en_annual.sel(year=slice(1998,2005)).transpose('lat','lon','year')),
                                 coords=[h_fw_en_annual.lat,h_fw_en_annual.lon],dims=['lat','lon'])
h_fw_en_ratio9805 = xr.DataArray(np.apply_along_axis(get_ratio, 2, 
                                            h_fw_en_annual.sel(year=slice(1998,2005)).transpose('lat','lon','year')),
                                 coords=[h_fw_en_annual.lat,h_fw_en_annual.lon],dims=['lat','lon'])

t = h_fw_en_annual.sel(year=slice(2010,2017)).year.astype(int)
h_fw_en_trend1017 = xr.DataArray(np.apply_along_axis(get_trend, 2, 
                                            h_fw_en_annual.sel(year=slice(2010,2017)).transpose('lat','lon','year')),
                                 coords=[h_fw_en_annual.lat,h_fw_en_annual.lon],dims=['lat','lon'])
h_fw_en_ratio1017 = xr.DataArray(np.apply_along_axis(get_ratio, 2, 
                                            h_fw_en_annual.sel(year=slice(2010,2017)).transpose('lat','lon','year')),
                                 coords=[h_fw_en_annual.lat,h_fw_en_annual.lon],dims=['lat','lon'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in double_scalars

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'1998-2005', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)

gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
#gl.rotate_labels = False
#gl.top_labels = False
#gl.right_labels = False
#gl.xlabel_style= {'size': 12, 'color': 'k'}
#gl.ylabel_style= {'size': 12, 'color': 'k'}
#p = ax.contourf(h_fw_en_trend9805.lon-0.5,h_fw_en_trend9805.lat-0.5,np.clip(h_fw_en_trend9805,-0.6,0.6),cmap='RdBu',
#                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
#ax.contourf(h_fw_en_ratio9805.lon-0.5,h_fw_en_ratio9805.lat-0.5,np.ma.masked_invalid(np.clip(h_fw_en_ratio9805,-2,2)),
#            levels=3, colors='none', hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

ax.add_geometries([gdf_nsea['geometry'][0]], cartopy.crs.PlateCarree(), facecolor='none', edgecolor=(0,0,0,1), 
                    linewidth=3, linestyle='-')
ax.add_geometries([gdf_spna['geometry'][0]], cartopy.crs.PlateCarree(), facecolor='none', edgecolor=(0,0,0,1), 
                    linewidth=3, linestyle='-')

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'1998-2005', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)

gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
#gl.rotate_labels = False
#gl.top_labels = False
#gl.right_labels = False
#gl.xlabel_style= {'size': 12, 'color': 'k'}
#gl.ylabel_style= {'size': 12, 'color': 'k'}
p = ax.contourf(h_fw_en_trend9805.lon-0.5,h_fw_en_trend9805.lat-0.5,np.clip(h_fw_en_trend9805,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(h_fw_en_ratio9805.lon-0.5,h_fw_en_ratio9805.lat-0.5,np.ma.masked_invalid(np.clip(h_fw_en_ratio9805,-2,2)),
            levels=3, colors='none', hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

ax.add_geometries([gdf_nsea['geometry'][0]], cartopy.crs.PlateCarree(), facecolor='none', edgecolor=(0,0,0,1), 
                    linewidth=3, linestyle='-')
ax.add_geometries([gdf_spna['geometry'][0]], cartopy.crs.PlateCarree(), facecolor='none', edgecolor=(0,0,0,1), 
                    linewidth=3, linestyle='-')

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'2010-2017', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)
gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
p = ax.contourf(h_fw_en_trend1017.lon-0.5,h_fw_en_trend1017.lat-0.5,np.clip(h_fw_en_trend1017,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(h_fw_en_ratio1017.lon-0.5,h_fw_en_ratio1017.lat-0.5,np.ma.masked_invalid(np.clip(h_fw_en_ratio1017,-2,2)),
            levels=3, colors='none', hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'1998-2005', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)
gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
p = ax.contourf(h_fw_ec_trend9805.lon-0.25,h_fw_ec_trend9805.lat-0.25,np.clip(h_fw_ec_trend9805,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(h_fw_ec_ratio9805.lon-0.25,h_fw_ec_ratio9805.lat-0.25,
            np.ma.masked_invalid(np.clip(h_fw_ec_ratio9805,-2,2)),levels=3, colors='none', 
            hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'2010-2017', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)
gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
p = ax.contourf(h_fw_ec_trend1017.lon-0.25,h_fw_ec_trend1017.lat-0.25,np.clip(h_fw_ec_trend1017,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(h_fw_ec_ratio1017.lon-0.25,h_fw_ec_ratio1017.lat-0.25,
            np.ma.masked_invalid(np.clip(h_fw_ec_ratio1017,-2,2)),levels=3, colors='none',
            hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %% [markdown]
# # Monthly seasonal anomalies

# %%
h_fw_ec_anom = h_fw_ec.groupby('time.month') - h_fw_ec.groupby('time.month').mean('time')
h_fw_en_anom = h_fw_en.groupby('time.month') - h_fw_en.groupby('time.month').mean('time')

# %%
t1i = '1998-01-01'
t1f = '2005-12-31'

t2i = '2010-01-01'
t2f = '2017-12-31'

# %%
FW_ec9805 = h_fw_ec_anom.sel(time=slice(t1i,t1f))
FW_ec1017 = h_fw_ec_anom.sel(time=slice(t2i,t2f))
FW_en9805 = h_fw_en_anom.sel(time=slice(t1i,t1f))
FW_en1017 = h_fw_en_anom.sel(time=slice(t2i,t2f))

# %%
# ECCOv4 1998-2005
t = FW_ec9805.time.astype(int)/1e9/3600/24/365.25
FW_ec9805_trend = xr.DataArray(np.apply_along_axis(get_trend, 2, FW_ec9805.transpose('lat','lon','time')),
                               coords=[FW_ec9805.lat,FW_ec9805.lon],dims=['lat','lon'])
FW_ec9805_ratio = xr.DataArray(np.apply_along_axis(get_ratio, 2, FW_ec9805.transpose('lat','lon','time')),
                               coords=[FW_ec9805.lat,FW_ec9805.lon],dims=['lat','lon'])

# ECCOv4 2010-2017
t = FW_ec1017.time.astype(int)/1e9/3600/24/365.25
FW_ec1017_trend = xr.DataArray(np.apply_along_axis(get_trend, 2, FW_ec1017.transpose('lat','lon','time')),
                               coords=[FW_ec1017.lat,FW_ec1017.lon],dims=['lat','lon'])
FW_ec1017_ratio = xr.DataArray(np.apply_along_axis(get_ratio, 2, FW_ec1017.transpose('lat','lon','time')),
                               coords=[FW_ec1017.lat,FW_ec1017.lon],dims=['lat','lon'])

# EN4 1998-2005
t = FW_en9805.time.astype(int)/1e9/3600/24/365.25
FW_en9805_trend = xr.DataArray(np.apply_along_axis(get_trend, 2, FW_en9805.transpose('lat','lon','time')),
                               coords=[FW_en9805.lat,FW_en9805.lon],dims=['lat','lon'])
FW_en9805_ratio = xr.DataArray(np.apply_along_axis(get_ratio, 2, FW_en9805.transpose('lat','lon','time')),
                               coords=[FW_en9805.lat,FW_en9805.lon],dims=['lat','lon'])

# EN4 2010-2017
t = FW_en1017.time.astype(int)/1e9/3600/24/365.25
FW_en1017_trend = xr.DataArray(np.apply_along_axis(get_trend, 2, FW_en1017.transpose('lat','lon','time')),
                               coords=[FW_en1017.lat,FW_en1017.lon],dims=['lat','lon'])
FW_en1017_ratio = xr.DataArray(np.apply_along_axis(get_ratio, 2, FW_en1017.transpose('lat','lon','time')),
                               coords=[FW_en1017.lat,FW_en1017.lon],dims=['lat','lon'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in double_scalars

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'1998-2005', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)

gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
#gl.rotate_labels = False
#gl.top_labels = False
#gl.right_labels = False
#gl.xlabel_style= {'size': 12, 'color': 'k'}
#gl.ylabel_style= {'size': 12, 'color': 'k'}
p = ax.contourf(FW_en9805_trend.lon-0.5,FW_en9805_trend.lat-0.5,np.clip(FW_en9805_trend,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(FW_en9805_ratio.lon-0.5, FW_en9805_ratio.lat-0.5,np.ma.masked_invalid(np.clip(FW_en9805_ratio,-2,2)),
            levels=3, colors='none', hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

ax.add_geometries([gdf_nsea['geometry'][0]], cartopy.crs.PlateCarree(), facecolor='none', edgecolor=(0,0,0,1), 
                    linewidth=3, linestyle='-')
ax.add_geometries([gdf_spna['geometry'][0]], cartopy.crs.PlateCarree(), facecolor='none', edgecolor=(0,0,0,1), 
                    linewidth=3, linestyle='-')

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

#plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'2010-2017', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)
gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
p = ax.contourf(FW_en1017_trend.lon-0.5,FW_en1017_trend.lat-0.5,np.clip(FW_en1017_trend,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(FW_en1017_ratio.lon-0.5, FW_en1017_ratio.lat-0.5,np.ma.masked_invalid(np.clip(FW_en1017_ratio,-2,2)),
            levels=3, colors='none', hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'1998-2005', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)
gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
p = ax.contourf(FW_ec9805_trend.lon-0.25,FW_ec9805_trend.lat-0.25,np.clip(FW_ec9805_trend,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(FW_ec9805_ratio.lon-0.25, FW_ec9805_ratio.lat-0.25,np.ma.masked_invalid(np.clip(FW_ec9805_ratio,-2,2)),
            levels=3, colors='none', hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()

# %%
fig = plt.figure(figsize=[7, 6])

ax = plt.axes(projection=cartopy.crs.LambertConformal(central_longitude=-45.0,central_latitude=50.0))
ax.set_title(r'2010-2017', fontsize=16, fontweight='bold')
ax.set_extent([-68, -6, 45, 83], cartopy.crs.Geodetic())
ax.add_feature(cartopy.feature.LAND,color='lightgrey',zorder=1)
ax.coastlines(resolution='50m',linewidth=1.0,zorder=2)
gl = ax.gridlines(cartopy.crs.PlateCarree(), draw_labels=False, linewidth=1.0, linestyle=':', color='k')
gl.xlocator = mticker.FixedLocator(np.arange(-120,60,10))
gl.ylocator = mticker.FixedLocator(np.arange(0,100,10))
p = ax.contourf(FW_ec1017_trend.lon-0.25,FW_ec1017_trend.lat-0.25,np.clip(FW_ec1017_trend,-0.6,0.6),cmap='RdBu',
                vmin=-0.6,vmax=0.6,levels = np.arange(-0.6,0.65,0.05),transform=cartopy.crs.PlateCarree())
ax.contourf(FW_ec1017_ratio.lon-0.25, FW_ec1017_ratio.lat-0.25,np.ma.masked_invalid(np.clip(FW_ec1017_ratio,-2,2)),
            levels=3, colors='none', hatches=['','...','...',''], transform=cartopy.crs.PlateCarree())

cb = fig.colorbar(p, orientation='vertical', shrink=0.9, ticks=np.arange(-0.6,0.7,0.1))
cb.ax.tick_params(labelsize=14)
cb.set_label(r'Trend in freshwater content (m yr$^{-1}$)', fontsize=16)

plt.savefig('/mnt/efs/figure.png')
plt.show()
